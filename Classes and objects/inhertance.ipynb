# %%
class game:
    def __init__(self,player,game_type):
        self.player=player
        self.game_type=game_type
    def play(self):
        print(f"{self.player} has entered the game")

# %%
class contra(game):
    def __init__(self,)
