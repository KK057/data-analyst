# %%
class Error(Exception):#base class
    pass
class dobException(Error):#derived class
    pass

# %%
name=input("Enter your name")
try:
    if not any(char.isdigit() for char in name):
        print(f"Good selection {name}")
    else:
        raise dobException
except dobException:
    print("Sorry invalid name")
# Out:
# Sorry invalid name
