# %%
#Polymorphism allows the same method/function  name to behave differently for different objects.
#Method overriding(type)

#Bse class
class Shape:
    def area(self):
        print("The area of the shape is")

#derived class 1
class Rectangle(Shape):
    def __init__(self,length,breadth):
        self.length=length
        self.breadth=breadth
    def area(self):
        return self.breadth*self.length
#Derived class2
class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return 3.14*self.radius*self.radius

# %%
rec=Rectangle(45,85)
rec.area()
# Out:
# 3825

# %%
cir=Circle(4)
print(cir.area())
# Out:
# 50.24

# %%
#Function that demonstrates polymorphism
def print_area(shape):
    print(f"The area of the shape is {shape.area()}")
    
rec1=Rectangle(52,82)
print(print_area(rec))
# Out:
# The area of the shape is 3825
# None

# %%
#Polymorphism with Abstract Base Classes
# It is used to create a blueprint/template class that other classes must follow.
from abc import ABC, abstractmethod

class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass

class Car(Vehicle):

    def start(self):
        print("Car starts with key")

c = Car()
c.start()

class Bike(Vehicle):
    pass

b = Bike()
# ABC says:

# “Any child class MUST implement these methods.”
# Out:
# Car starts with key
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 22
#      19 class Bike(Vehicle):
#      20     pass
# ---> 22 b = Bike()
#
# TypeError: Can't instantiate abstract class Bike without an implementation for abstract method 'start'
