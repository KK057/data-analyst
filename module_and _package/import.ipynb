# %%
from math import *
print(sqrt(52))
print(pi)
# Out:
# 7.211102550927978
# 3.141592653589793

# %%
from package.maths import add
add(42,647)
# Out:
# 689

# %%
from package import maths
maths.add(6,55)
# Out:
# 61

# %%
from package import maths
maths.subtraction(6,55)
# Out:
# -49

# %%
#random
import random 
print(random.randint(1,10))# 1 to 10 an value
print(random.choice(['apple','orange','coca-cola','dance']))
# Out:
# 7
# orange

# %%
#File and directory access
import os
print(os.getcwd())#current working directory
# Out:
# c:\Users\bky84\OneDrive\Documents\Desktop\data analyst\module_and _package

# %%
os.makedirs("test_dir", exist_ok=True)#makes folder

# %%
#High level operations on files and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
#data serialization
import json
data={'Name':'kaushik','Age':'64'}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))
parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"Name": "kaushik", "Age": "64"}
# <class 'str'>
# {'Name': 'kaushik', 'Age': '64'}
# <class 'dict'>

# %%
#csv
import csv
with open('example.csv' ,mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Shiva','455'])
with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Shiva', '455']

# %%
#datetime
from datetime import datetime,timedelta
now=datetime.now()
yesterday=now-timedelta(days=1)
print(yesterday)
print(now)
# Out:
# 2026-04-22 22:07:40.383351
# 2026-04-23 22:07:40.383351

# %%
#time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1776962260.400584
# 1776962262.4015782
